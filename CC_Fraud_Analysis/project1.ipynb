# %%
# Dependencies and Libaries
import matplotlib.pyplot as plt
from pathlib import Path
import pandas as pd
import numpy as np
from scipy.stats import linregress
import requests

# %%
# Load the data
card_fraud_path_load = Path("resource/credit_card_fraud.csv")
card_data = pd.read_csv(card_fraud_path_load)
card_data.head()
# Out:
#   Transaction Date and Time  Transaction Amount        Cardholder Name  \
# 0       2022-09-24 13:54:27              285.88            Shray Soman
# 1       2020-07-24 11:20:13             1777.32         Lakshit Bakshi
# 2       2023-03-18 01:05:36             3939.01             Riya Bobal
# 3       2021-01-07 21:53:04              376.44  Mohanlal Balakrishnan
# 4       2021-12-16 06:22:24             1687.33            Mannat Rout
#
#                    Card Number (Hashed or Encrypted)  \
# 0  daca51bffe0fc4eaaa7c430917f94b75fd893712492254...
# 1  d5366dd9be3a0266c0252baceaa6332210ed4dbd0ef252...
# 2  4737a6384aa1c3c31f7768b86633d6a8401dd6ab4a8ff1...
# 3  4721806eed8f2663bb597ff13e79a294de318358fbb54b...
# 4  9deacc3a9efd6e382826d400620aca5f23ed94327578e5...
#
#                  Merchant Name  Merchant Category Code (MCC)  \
# 0  Rajagopalan, Ghose and Kant                          3590
# 1                     Sule PLC                          7277
# ...

# %%
# Convert the 'date' column to datetime
card_data['Transaction Date and Time'] = pd.to_datetime(card_data['Transaction Date and Time'])

# %%
# Create separate columns for date and time
card_data['Date'] = card_data['Transaction Date and Time'].dt.date
card_data['Time'] = card_data['Transaction Date and Time'].dt.time

# Remove the new columns from their current positions
Date = card_data.pop('Date')
Time = card_data.pop('Time')

# Insert the new columns at the desired positions
card_data.insert(1, 'Date', Date)
card_data.insert(2,'Time', Time)

card_data.head()
# Out:
#   Transaction Date and Time        Date      Time  Transaction Amount  \
# 0       2022-09-24 13:54:27  2022-09-24  13:54:27              285.88
# 1       2020-07-24 11:20:13  2020-07-24  11:20:13             1777.32
# 2       2023-03-18 01:05:36  2023-03-18  01:05:36             3939.01
# 3       2021-01-07 21:53:04  2021-01-07  21:53:04              376.44
# 4       2021-12-16 06:22:24  2021-12-16  06:22:24             1687.33
#
#          Cardholder Name                  Card Number (Hashed or Encrypted)  \
# 0            Shray Soman  daca51bffe0fc4eaaa7c430917f94b75fd893712492254...
# 1         Lakshit Bakshi  d5366dd9be3a0266c0252baceaa6332210ed4dbd0ef252...
# 2             Riya Bobal  4737a6384aa1c3c31f7768b86633d6a8401dd6ab4a8ff1...
# 3  Mohanlal Balakrishnan  4721806eed8f2663bb597ff13e79a294de318358fbb54b...
# 4            Mannat Rout  9deacc3a9efd6e382826d400620aca5f23ed94327578e5...
#
#                  Merchant Name  Merchant Category Code (MCC)  \
# ...
